# %% [markdown]
# <a href="https://colab.research.google.com/github/Pernach/Homework8/blob/main/YOLOv8_lions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
#
#   <a href="https://ultralytics.com/yolov8" target="_blank">
#     <img width="1024", src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov8/banner-yolov8.png"></a>
#
#
# <br>
#   <a href="https://console.paperspace.com/github/ultralytics/ultralytics"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="Run on Gradient"/></a>
#   <a href="https://colab.research.google.com/github/ultralytics/ultralytics/blob/main/examples/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#   <a href="https://www.kaggle.com/ultralytics/yolov8"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# <br>
#
# Welcome to the Ultralytics YOLOv8 🚀 notebook! <a href="https://github.com/ultralytics/ultralytics">YOLOv8</a> is the latest version of the YOLO (You Only Look Once) AI models developed by <a href="https://ultralytics.com">Ultralytics</a>. This notebook serves as the starting point for exploring the various resources available to help you get started with YOLOv8 and understand its features and capabilities.
#
# YOLOv8 models are fast, accurate, and easy to use, making them ideal for various object detection and image segmentation tasks. They can be trained on large datasets and run on diverse hardware platforms, from CPUs to GPUs.
#
# We hope that the resources in this notebook will help you get the most out of YOLOv8. Please browse the YOLOv8 <a href="https://docs.ultralytics.com/">Docs</a> for details, raise an issue on <a href="https://github.com/ultralytics/ultralytics">GitHub</a> for support, and join our <a href="https://discord.gg/n6cFeSPZdD">Discord</a> community for questions and discussions!
#
# </div>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive"
# Out:
# 'Colab Notebooks'  'PICKEM Легенды 2021.gform'
#  CV2.ipynb	    ScannerMini
#  data		    Simplenet.ipynb
#  flying-vehicles    zoo.mp4
#  lions_ds	   'Порталы услуг помощи путешественникам.gsheet'
#  Mobilnet.ipynb    'Скан 22 июля 2021 г., 10.18.pdf'

# %% [markdown]
# # Setup
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/requirements.txt) and check software and hardware.

# %%
# !git clone https://github.com/ultralytics/ultralytics  # clone
#%cd yolov8
# %pip install -qr requirements.txt  # install
import ultralytics
#ultralytics.checks()
# Out:
# fatal: destination path 'ultralytics' already exists and is not an empty directory.
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
#@title Select YOLOv8 🚀 logger {run: 'auto'}
logger = 'Comet' #@param ['Comet', 'ClearML', 'TensorBoard']

if logger == 'Comet':
  # %pip install -q comet_ml
  import comet_ml; comet_ml.init()
elif logger == 'ClearML':
  # %pip install -q clearml
  import clearml; clearml.browser_login()
elif logger == 'TensorBoard':
  # %load_ext tensorboard
  # %tensorboard --logdir runs/train
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.2/532.2 kB 14.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 88.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.7/206.7 kB 23.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 14.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.1/510.1 kB 47.5 MB/s eta 0:00:00

# %% [markdown]
# # 3. Train
#
# <p align=""><a href="https://bit.ly/ultralytics_hub"><img width="1000" src="https://github.com/ultralytics/assets/raw/main/yolov8/banner-integrations.png"/></a></p>
#
# Train YOLOv8 on [Detect](https://docs.ultralytics.com/tasks/detect/), [Segment](https://docs.ultralytics.com/tasks/segment/), [Classify](https://docs.ultralytics.com/tasks/classify/) and [Pose](https://docs.ultralytics.com/tasks/pose/) datasets. See [YOLOv8 Train Docs](https://docs.ultralytics.com/modes/train/) for more information.

# %%
# Train YOLOv8 on my dataset for 50 epochs
# !yolo train model=yolov8x.pt data="/content/drive/MyDrive/lions_ds/data.yaml" epochs=100 imgsz=640
# Out:
# Ultralytics YOLOv8.0.114 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ##Результаты обучения:
#
# https://www.comet.com/pernach/general/view/new/panels

# %% [markdown]
# # 1. Predict
#
# YOLOv8 may be used directly in the Command Line Interface (CLI) with a `yolo` command for a variety of tasks and modes and accepts additional arguments, i.e. `imgsz=640`. See a full list of available `yolo` [arguments](https://docs.ultralytics.com/usage/cfg/) and other details in the [YOLOv8 Predict Docs](https://docs.ultralytics.com/modes/train/).

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model="/content/runs/detect/train2/weights/best.pt" source="/content/drive/My Drive/zoo.mp4"
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# video 1/1 (1357/6354) /content/drive/My Drive/zoo.mp4: 384x640 (no detections), 39.7ms
# video 1/1 (1358/6354) /content/drive/My Drive/zoo.mp4: 384x640 (no detections), 38.1ms
# video 1/1 (1359/6354) /content/drive/My Drive/zoo.mp4: 384x640 (no detections), 36.6ms
# video 1/1 (1360/6354) /content/drive/My Drive/zoo.mp4: 384x640 (no detections), 36.1ms
# video 1/1 (1361/6354) /content/drive/My Drive/zoo.mp4: 384x640 (no detections), 37.1ms
# video 1/1 (1362/6354) /content/drive/My Drive/zoo.mp4: 384x640 (no detections), 38.5ms
# video 1/1 (1363/6354) /content/drive/My Drive/zoo.mp4: 384x640 (no detections), 38.7ms
# video 1/1 (1364/6354) /content/drive/My Drive/zoo.mp4: 384x640 (no detections), 36.7ms
# video 1/1 (1365/6354) /content/drive/My Drive/zoo.mp4: 384x640 (no detections), 36.7ms
# video 1/1 (1366/6354) /content/drive/My Drive/zoo.mp4: 384x640 (no detections), 37.3ms
# ...

# %% [markdown]
# # 2. Val
# Validate a model's accuracy on the [COCO](https://cocodataset.org/#home) dataset's `val` or `test` splits. The latest YOLOv8 [models](https://github.com/ultralytics/ultralytics#models) are downloaded automatically the first time they are used. See [YOLOv8 Val Docs](https://docs.ultralytics.com/modes/val/) for more information.

# %%
# Download COCO val
import torch
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')  # download (780M - 5000 images)
# !unzip -q tmp.zip -d datasets && rm tmp.zip  # unzip

# %%
# Validate YOLOv8n on COCO128 val
# !yolo val model=yolov8n.pt data="/content/drive/MyDrive/lions_ds/data.yaml"
# Out:
# Ultralytics YOLOv8.0.71 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# Dataset 'coco128.yaml' images not found ⚠️, missing paths ['/content/datasets/coco128/images/train2017']
# ...
# 100% 6.66M/6.66M [00:01<00:00, 6.80MB/s]
# Unzipping /content/datasets/coco128.zip to /content/datasets...
# Dataset download success ✅ (2.2s), saved to /content/datasets
#
# ...
# 100% 755k/755k [00:00<00:00, 107MB/s]
# val: Scanning /content/datasets/coco128/labels/train2017... 126 images, 2 backgrounds, 80 corrupt: 100% 128/128 [00:00<00:00, 1183.28it/s]
# val: New cache created: /content/datasets/coco128/labels/train2017.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:12<00:00,  1.54s/it]
#                    all        128        929       0.64      0.537      0.605      0.446
# ...
